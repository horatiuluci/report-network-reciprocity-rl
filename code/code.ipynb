# %%
import numpy as np
import math as m
import networkx as nx
import matplotlib.pyplot as plt
from time import time
import seaborn as sns

# %%
def get_stimulus(A, beta, reward):
    arg = beta*(reward - A)
    return m.tanh(arg)

# %%
def update_p(aspiration_level, beta, reward, prev_action, p):
    s = get_stimulus(aspiration_level, beta, reward)
    if prev_action == 0: #previous action = cooperation
        if s >= 0:
            return p + (1-p)*s
        else:
            return p + p*s
    else: #previous action = defect
        if s >= 0:
            return p - p*s
        else:
            return p - (1-p)*s

# %%
def misimplement_prob_update(eps, prob):
    return prob*(1-eps) + (1-prob)*eps

# %%
def get_payoff_matrix(b,c):
    return np.array([[b-c, -c],
                     [b, 0]])

# %%
def get_payoffs(p1, p2):
    return payoff_mat[p1][p2]

# %%
def create_ring_graph(N, k):
    return nx.watts_strogatz_graph(N, k, 0)


#pos = nx.circular_layout(G_small_ring)
#plt.figure(3,figsize=(20,20)) 
#nx.draw_networkx(G_small_ring, pos=pos, with_labels=False)

# %%
def simulate_game(G, payoff_mat, k, rounds, A, beta, eps):
    nodes = len(list(G.nodes))
    probas = np.array([0.8 for _ in range(nodes)])
    counts = np.zeros(rounds)
    assortment=np.zeros(rounds)
    for r in range(rounds):
        payoffs = np.zeros(nodes)
        actions = np.random.binomial(1, p = (1 - probas))
        #print(actions)
        #assortment[r]=actions.count(0)
        countC=0
        countD=0
        for node in list(G.nodes):
            for neighbour in list(G.neighbors(node)):
                if(actions[neighbour]==0 and actions[node]==0):
                  countC+=1
                elif(actions[neighbour]==0 and actions[node]==1):
                  countD+=1
                payoffs[node] += get_payoffs(actions[node], actions[neighbour])
            payoffs[node]/k
        for node in list(G.nodes):
            probas[node] = misimplement_prob_update(eps, update_p(A, beta, payoffs[node], actions[node], probas[node]))
        counts[r] = nodes - np.count_nonzero(actions)
        assortment[r]=(countC-countD)/(nodes*k)
    assort=np.sum(assortment)/rounds
    print(assort)
    return counts/nodes

# %%
N = 100
k = 2
G = create_ring_graph(N, k)
A = 1
beta = 0.2
eps = 0.05
payoff_mat = get_payoff_matrix(6, 1)

# %%
coops_lvl = []

#for i in range(1000):
#    coops_lvl.append(simulate_game(G, payoff_mat, k, 25, A, beta, eps))
startTime = time()
A_values = np.linspace(-1, 5, num = 100)
eps_values = np.linspace(0, 0.5, num = 100)

heatmap = np.zeros((100,100))

for a_i in range(len(A_values)):
    for eps_i in range(len(eps_values)):
        heatmap[eps_i][a_i] = simulate_game(G, payoff_mat, k, 25, A_values[a_i], beta, eps_values[eps_i])[-1]

endTime = time()
print("\nSimulating took {} seconds".format(round(endTime - startTime)))
np.save(file = "test.npy", arr = heatmap)
# Out:
# 0.47239999999999993
# 0.2696
# 0.3116
# 0.5052
# 0.20800000000000002
# 0.20800000000000002
# 0.25880000000000003
# 0.12
# 0.10279999999999999
# 0.0872
# 0.16399999999999998
# 0.19079999999999997
# 0.14959999999999998
# 0.1176
# 0.11760000000000001
# 0.1496
# 0.11280000000000001
# 0.11679999999999997
# 0.09759999999999999
# 0.1044
# 0.003999999999999999
# 0.0416
# 0.029600000000000005
# 0.0368
# 0.043199999999999995
# 0.0336
# 0.0404
# 0.04880000000000001
# 0.028399999999999998
# 0.0352
# 0.026399999999999996
# 0.0292
# 0.0212
# 0.0252
# 0.0016000000000000025
# 0.022400000000000007
# 0.032
# 0.025599999999999998
# 0.0188
# 0.0096
# 0.03240000000000001
# 0.0192
# 0.032
# 0.06040000000000001
# -0.003200000000000005
# 0.026799999999999997
# 0.0364
# 0.028000000000000004
# -0.006000000000000002
# 0.026799999999999997
# 0.016800000000000002
# -0.014400000000000003
# 0.0208
# 0.022000000000000002
# 0.0012000000000000025
# 0.020399999999999995
# -0.011600000000000001
# -0.003999999999999998
# 0.029200000000000004
# 0.0044
# 0.010799999999999997
# 0.0039999999999999975
# 0.007600000000000001
# 0.018799999999999997
# 0.014400000000000003
# 0.016399999999999998
# -0.0052000000000000015
# 0.0076
# 0.027200000000000002
# 0.011600000000000001
# 0.022000000000000002
# 0.010799999999999997
# 0.0096
# 0.0184
# 0.0176
# 0.032799999999999996
# 0.019600000000000003
# 0.04
# 0.0372
# 0.0136
# -0.0008000000000000045
# 0.020799999999999992
# 0.04
# -3.885780586188048e-18
# 0.008
# 0.015200000000000002
# 0.5264
# 0.38839999999999997
# 0.3864
# 0.254
# 0.33399999999999996
# 0.1776
# 0.1628
# 0.2332
# 0.16879999999999998
# 0.2188
# 0.12359999999999997
# 0.1904
# 0.0496
# 0.0908
# 0.1284
# 0.106
# 0.008000000000000002
# 0.032799999999999996
# 0.0956
# 0.0472
# 0.0788
# 0.11879999999999999
# 0.019600000000000003
# 0.0592
# 0.088
# 0.036
# 0.007200000000000001
# 0.045200000000000004
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-90689bc0a572> in <module>()
#      11 for a_i in range(len(A_values)):
#      12     for eps_i in range(len(eps_values)):
# ---> 13         heatmap[eps_i][a_i] = simulate_game(G, payoff_mat, k, 25, A_values[a_i], beta, eps_values[eps_i])[-1]
#      14
#      15 endTime = time()
#
# <ipython-input-8-b6fb338db5ab> in simulate_game(G, payoff_mat, k, rounds, A, beta, eps)
#      15                 if(actions[neighbour]==0 and actions[node]==0):
#      16                   countC+=1
# ---> 17                 elif(actions[neighbour]==0 and actions[node]==1):
#      18                   countD+=1
#      19                 payoffs[node] += get_payoffs(actions[node], actions[neighbour])
#
# KeyboardInterrupt:

# %%
sns.heatmap(heatmap.transpose(), square = True, vmin = np.amin(heatmap), vmax = np.amax(heatmap), annot = False, fmt = ".4f", cmap = "YlGnBu")
plt.xticks([-1,5])
plt.yticks([0,0.5])
plt.show()

# %%
"""avg_coops = np.array([0. for _ in range(50)])
for i in range(50):
    for trial in coops_lvl:
        avg_coops[i] += trial[i]
avg_coops = avg_coops/100"""

# %%
def plot_coops(coops_lvl, r):
    x = np.arange(r)
    plt.plot(x, coops_lvl)
    plt.show()

# %%
plot_coops(avg_coops, 50)

# %%
lbls = np.random.choice(100, replace=False, size=100)
mapping = {i : lbls[i] for i in range(100)}
H = nx.relabel_nodes(G, mapping)
